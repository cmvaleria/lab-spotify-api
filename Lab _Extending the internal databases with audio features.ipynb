# %% [markdown]
# # Lab | Extending the internal databases with audio features

# %% [markdown]
# ### 1. Create a function to search a given single song in the Spotify API: search_song(title, artist).

# %% [markdown]
# Loading Credentials:

# %%
import sys
from config import *

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= Client_ID,
                                                           client_secret= Client_Secret))

# %%
import time

# %%
def search_song(title, artist):
    time.sleep(5)
    try:
        results = sp.search(q=title+','+artist, limit=5)
        return results['tracks']['items'][-1]['id']
    except: 
        return 'na'

# %%
# results['tracks']['items'][-1][]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#   'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#   'id': '6PRPYATK5VvjZ2p911y6U0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#     'width': 64}],
#   'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#   'release_date': '2001-04-23',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#    'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#    'id': '00sazWvoTLOqg5MFwC68Um',
#    'name': 'Yann Tiersen',
#    'type': 'artist',
#    'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'ET',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 135906,
#  'explicit': False,
#  'external_ids': {'isrc': 'FR91U0100001'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7MIN37CiVP1lVjqKNmLMWk'},
#  'href': 'https://api.spotify.com/v1/tracks/7MIN37CiVP1lVjqKNmLMWk',
#  'id': '7MIN37CiVP1lVjqKNmLMWk',
#  'is_local': False,
#  'name': "La valse d'Amélie",
#  'popularity': 55,
#  'preview_url': 'https://p.scdn.co/mp3-preview/3428e643b2ecbe85c64c4cd2192ad651d8e3b204?cid=ded0ce1be8b44a879ce3d5ad6c2b9ade',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:7MIN37CiVP1lVjqKNmLMWk'}

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# ### <span style="color:blue"> CHANGE THE NUMBER FILE </span>

# %%
not_hot_songs = pd.read_csv('files_for_lab/not_hot_songs3.csv')
not_hot_songs = not_hot_songs.drop(columns={'Unnamed: 0','index'})

# %% [markdown]
# ### XXX <span style="color:red"> ITERATE HERE </span> XXX

# %%
not_hot_songs['id'] = not_hot_songs.apply(lambda row: search_song(row['song'], row['artist']), axis=1)

# %%
not_hot_songs.head()

# %% [markdown]
# ### <span style="color:blue"> EXPORT AND CHANGE THE NUMBER </span>

# %%
not_hot_songs3.to_csv('not_hot_songs3_ids.csv',index=False)

# %% [markdown]
# ### 2. Create a function get_audio_features(list_of_songs) to obtain the audio features of a given list of songs (the content of list_of_songs can be the href/id/uri).

# %% [markdown]
# ### 3. Once the previous function has been created, create another function add_audio_features(df, audio_features_df) to concat a given dataframe with the dataframe containing the audio features alongside any other desired info, and return the extended data frame. Replace the old internal files of songs (hot and not hot) with the extended data frames with the audio features and save them into separate files on the disk.
